# %%
import altair as alt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
brush = alt.selection_interval(encodings=['x','y'])

chart1 = alt.Chart.from_dict({
    "data":{"url":'https://raw.githubusercontent.com/UIUC-iSchool-DataViz/is445_data/main/bfro_reports_fall2022.csv'},
    "mark":"bar",
    "width":600,
    "height":300,
    "encoding":{
    "x":{"field":"season", "type":"ordinal", "title":"Season"},
    "y":{"field":"visibility", "type":"quantitative", "title":"Visibility"},
  } 
}).add_selection(
    brush
)

chart2 = alt.Chart.from_dict({
    "data":{"url":'https://raw.githubusercontent.com/UIUC-iSchool-DataViz/is445_data/main/bfro_reports_fall2022.csv'},
    "mark":"bar",
    "width":600,
    "height":300,
    "encoding":{
    "x":{"field":"state", "type":"ordinal", "title":"State"},
    "y":{"field":"wind_speed", "type":"quantitative", "title":"Wind Speed"},
    }#// end encoding
}).transform_filter(
    brush
)

chart = chart1 | chart2
chart
# Out:
# /usr/local/lib/python3.11/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'add_selection' is deprecated. Use 'add_params' instead.
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# alt.HConcatChart(...)

# %%
alt.data_transformers.enable('json')
panzoom = alt.selection_interval(bind='scales')


building_inv_chart1 = alt.Chart(alt.Data(values=buildings)).mark_bar().encode(
    x='Year Constructed:Q',
    y='Square Footage:Q',
    tooltip=['Year Constructed', 'Square Footage', 'Bldg Status']  # Adding tooltips here
).properties(
    width=800,
    height=300
).add_selection(  # Corrected method name here
    panzoom 
)

# Second chart
building_inv_chart2 = alt.Chart(alt.Data(values=buildings)).mark_bar().encode(
    x=alt.X('Bldg Status:N', title='Building Status'),
    y=alt.Y('count(Bldg Status):Q', title='Count')
).properties(
    width=800,
    height=300
).add_selection(  # Corrected method name here
    panzoom  
)

# Combine charts
building_charts = building_inv_chart1 | building_inv_chart2
building_charts
# Out:
# /usr/local/lib/python3.11/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'add_selection' is deprecated. Use 'add_params' instead.
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# /usr/local/lib/python3.11/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'add_selection' is deprecated. Use 'add_params' instead.
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.11/site-packages/altair/vegalite/v5/api.py in ?(self, include, exclude)
#    2308         # see https://github.com/ipython/ipython/issues/11038
#    2309         try:
#    2310             dct = self.to_dict(context={"pre_transform": False})
#    2311         except Exception:
# -> 2312             utils.display_traceback(in_ipython=True)
# ...

# %%
alt.data_transformers.enable('json')
panzoom = alt.selection_interval(bind='scales')

building_inv_chart1 = alt.Chart(buildings).mark_bar().encode(
    x='Year Constructed:Q',
    y='Square Footage:Q',
    tooltip=['Year Constructed', 'Square Footage', 'Bldg Status']  # Adding tooltips here
).properties(
    width=800,
    height=300
).add_params(
    panzoom 
)

building_inv_chart2 = alt.Chart(buildings).mark_bar().encode(
    x=alt.X('Bldg Status:N', title='Building Status'),
    y=alt.Y('count(Bldg Status):Q', title='Count')
).properties(
    width=800,
    height=300
).add_params(
    panzoom  
)

building_charts = building_inv_chart1 | building_inv_chart2
building_charts
# Out:
# alt.HConcatChart(...)

# %%
myJekyllDir = '/Users/seoyoungyoon/seoyoung-aspyn.github.io/assets/json/'
building_charts.save(myJekyllDir + 'building_charts.json')
